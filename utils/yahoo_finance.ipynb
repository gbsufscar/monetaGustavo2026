# %%
YAHOO_FINANCE_TRADUZIDO = {
    # ============================================
    # IDENTIFICAÇÃO DA AÇÃO
    # ============================================
    "symbol": "símbolo",
    "shortName": "nome curto",
    "longName": "nome completo",
    "market": "mercado",
    "quoteType": "tipo de ativo",
    "typeDisp": "tipo (exibição)",
    "language": "idioma",

    # ============================================
    # PREÇOS E VARIAÇÕES
    # ============================================
    "currentPrice": "preço atual",
    "open": "abertura",
    "previousClose": "fechamento anterior",
    "dayHigh": "máxima do dia",
    "dayLow": "mínima do dia",
    "regularMarketOpen": "abertura do mercado regular",
    "regularMarketPreviousClose": "fechamento anterior do mercado regular",
    "regularMarketPrice": "preço do mercado regular",
    "regularMarketDayHigh": "máxima do mercado regular",
    "regularMarketDayLow": "mínima do mercado regular",
    "regularMarketDayRange": "intervalo do mercado regular",
    "regularMarketChange": "variação no mercado regular",
    "regularMarketChangePercent": "variação percentual no mercado regular",
    "52WeekChange": "variação de 52 semanas",
    "SandP52WeekChange": "variação do S&P em 52 semanas",
    "allTimeHigh": "máxima histórica",
    "allTimeLow": "mínima histórica",
    "fiftyTwoWeekHigh": "máxima de 52 semanas",
    "fiftyTwoWeekLow": "mínima de 52 semanas",
    "fiftyTwoWeekRange": "intervalo de 52 semanas",
    "fiftyTwoWeekHighChange": "mudança da máxima de 52 semanas",
    "fiftyTwoWeekLowChange": "mudança da mínima de 52 semanas",
    "fiftyTwoWeekHighChangePercent": "percentual de mudança da máxima de 52 semanas",
    "fiftyTwoWeekLowChangePercent": "percentual de mudança da mínima de 52 semanas",
    "fiftyTwoWeekChangePercent": "variação percentual em 52 semanas",
    "priceHint": "dica de preço",
    "ask": "preço ask",
    "askSize": "tamanho ask",
    "bid": "preço bid",
    "bidSize": "tamanho bid",

    # ============================================
    # VOLUME E LIQUIDEZ
    # ============================================
    "averageDailyVolume10Day": "volume médio diário (10 dias)",
    "averageDailyVolume3Month": "volume médio diário (3 meses)",
    "averageVolume": "volume médio",
    "averageVolume10days": "volume médio (10 dias)",
    "regularMarketVolume": "volume do mercado regular",
    "volume": "volume",
    "currentRatio": "índice de liquidez corrente",
    "quickRatio": "índice de liquidez seca",

    # ============================================
    # FUNDAMENTOS FINANCEIROS
    # ============================================
    "marketCap": "valor de mercado",
    "priceToEarnings": "preço/lucro (P/L)",
    "trailingPE": "P/L histórico",
    "forwardPE": "P/L futuro",
    "earningsPerShare": "lucro por ação (LPA)",
    "epsTrailingTwelveMonths": "LPA últimos 12 meses",
    "bookValue": "valor patrimonial por ação",
    "priceToBook": "preço/valor patrimonial (P/VP)",
    "beta": "beta (risco relativo)",
    "revenuePerShare": "receita por ação",
    "revenueGrowth": "crescimento da receita",
    "profitMargins": "margem de lucro",
    "grossMargins": "margem bruta",
    "grossProfits": "lucro bruto",
    "operatingMargins": "margem operacional",
    "returnOnAssets": "retorno sobre ativos",
    "returnOnEquity": "retorno sobre patrimônio",

    # ============================================
    # DIVIDENDOS E DATAS IMPORTANTES
    # ============================================
    "dividendRate": "taxa de dividendos",
    "dividendYield": "dividend yield",
    "fiveYearAvgDividendYield": "dividend yield médio de 5 anos",
    "trailingAnnualDividendRate": "taxa anual de dividendos",
    "trailingAnnualDividendYield": "dividend yield anual",
    "lastDividendDate": "data do último dividendo",
    "lastDividendValue": "valor do último dividendo",
    "exDividendDate": "data ex-dividendo",
    "lastSplitDate": "data do último split",
    "lastSplitFactor": "fator do último split",
    "lastFiscalYearEnd": "fim do último ano fiscal",
    "nextFiscalYearEnd": "fim do próximo ano fiscal",
    "firstTradeDateMilliseconds": "data do primeiro pregão (ms)",

    # ============================================
    # DRE – FLUXO DE CAIXA – ENDIVIDAMENTO
    # ============================================
    "ebitda": "ebitda",
    "ebitdaMargins": "margem ebitda",
    "operatingCashflow": "fluxo de caixa operacional",
    "freeCashflow": "fluxo de caixa livre",
    "totalCash": "caixa total",
    "totalCashPerShare": "caixa por ação",
    "totalDebt": "dívida total",
    "debtToEquity": "dívida sobre patrimônio",
    "netIncomeToCommon": "lucro líquido atribuível aos acionistas",
    "totalRevenue": "receita total",

    # ============================================
    # RISCOS E ESG
    # ============================================
    "auditRisk": "risco de auditoria",
    "boardRisk": "risco do conselho",
    "compensationRisk": "risco de compensação",
    "overallRisk": "risco geral",
    "shareHolderRightsRisk": "risco dos direitos dos acionistas",
    "esgPopulated": "esg populado",

    # ============================================
    # AÇÕES E ESTRUTURA SOCIETÁRIA
    # ============================================
    "sharesOutstanding": "ações em circulação",
    "floatShares": "ações em circulação (float)",
    "impliedSharesOutstanding": "ações implícitas em circulação",
    "heldPercentInsiders": "percentual detido por insiders",
    "heldPercentInstitutions": "percentual detido por instituições",

    # ============================================
    # SETOR, INDÚSTRIA E CLASSIFICAÇÃO
    # ============================================
    "sector": "setor",
    "sectorDisp": "setor (exibição)",
    "sectorKey": "chave do setor",
    "industry": "indústria",
    "industryDisp": "indústria (exibição)",
    "industryKey": "chave da indústria",

    # ============================================
    # DADOS DE MERCADO E BOLSA
    # ============================================
    "exchange": "bolsa",
    "fullExchangeName": "nome completo da bolsa",
    "exchangeTimezoneName": "fuso horário da bolsa",
    "exchangeTimezoneShortName": "sigla do fuso da bolsa",
    "exchangeDataDelayedBy": "atraso dos dados da bolsa",
    "marketState": "estado do mercado",
    "gmtOffSetMilliseconds": "offset GMT (ms)",
    "sourceInterval": "intervalo da fonte",

    # ============================================
    # RECOMENDAÇÕES DE ANALISTAS
    # ============================================
    "averageAnalystRating": "classificação média dos analistas",
    "numberOfAnalystOpinions": "número de opiniões de analistas",
    "recommendationKey": "recomendação",
    "recommendationMean": "média das recomendações",
    "targetHighPrice": "preço-alvo máximo",
    "targetLowPrice": "preço-alvo mínimo",
    "targetMeanPrice": "preço-alvo médio",
    "targetMedianPrice": "preço-alvo mediano",

    # ============================================
    # LOCALIZAÇÃO E IDENTIFICAÇÃO
    # ============================================
    "address1": "endereço 1",
    "city": "cidade",
    "state": "estado",
    "country": "país",
    "zip": "cep",
    "phone": "telefone",
    "website": "site",

    # ============================================
    # FUNCIONÁRIOS E GOVERNANÇA
    # ============================================
    "companyOfficers": "executivos da empresa",
    "executiveTeam": "equipe executiva",
    "fullTimeEmployees": "funcionários em tempo integral",
    "governanceEpochDate": "data de governança"
}

# %%
# Transformar o dicionário em um arquivo JSON
import json
from pathlib import Path

output_path = Path("yahoo_finance_traduzido.json")
with output_path.open("w", encoding="utf-8") as f:
    json.dump(YAHOO_FINANCE_TRADUZIDO, f, ensure_ascii=False, indent=2)

print(f"Arquivo JSON salvo em: {output_path.resolve()}")
# Out:
# Arquivo JSON salvo em: C:\Users\gbsuf\OneDrive\ambiente_programacao\moneta_Gustavo\utils\yahoo_finance_traduzido.json
